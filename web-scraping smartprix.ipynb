# %%
with open('smartprix.html','r',encoding='utf-8') as f:
    html = f.read()

# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd

# %%
soup = BeautifulSoup(html,'lxml')

# %%
container = soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'})

# %%
names = []
prices = []
ratings = []
sim = []
processor = []
ram = []
battery = []
display = []
camera = []
card = []
os = []

for i in soup.find_all('div',{'class':'sm-product has-tag has-features has-actions'}):
    try:
        names.append(i.find('h2').text)
    except:
        names.append(np.nan)
    try:
        prices.append(i.find('span',{'class':'price'}).text)
    except:
        price.append(np.nan)
    try:
        ratings.append(i.find('div',{'class':'score rank-2-bg'}).find('b').text)
    except:
        ratings.append(np.nan)
        
    x = i.find('ul',{'class':'sm-feat specs'}).find_all('li')
    try:
        sim.append(x[0].text)
    except:
        sim.append(np.nan)
    try:
        processor.append(x[1].text)
    except:
        processor.append(np.nan)
    try:    
        ram.append(x[2].text)
    except:
        ram.append(np.nan)
    try:
        battery.append(x[3].text)
    except:
        battery.append(np.nan)
    try:
        display.append(x[4].text)
    except:
        display.append(np.nan)
    try:
        camera.append(x[5].text)
    except:
        camera.append(np.nan)
    try:
        card.append(x[6].text)
    except:
        card.append(np.nan)
    try:
        os.append(x[7].text)
    except:
        os.append(np.nan)

# %%
len(name)
# Out:
# 960

# %%
len(price)
# Out:
# 960

# %%
len(score)
# Out:
# 960

# %%
df = pd.DataFrame({
    'model':names,
    'price':prices,
    'rating':ratings,
    'sim':sim,
    'processor':processor,
    'ram':ram,
    'battery':battery,
    'display':display,
    'camera':camera,
    'card':card,
    'os':os
})

# %%
df.isnull().sum()
# Out:
# model          0
# price          0
# rating       157
# sim            0
# processor      0
# ram            0
# battery        0
# display        0
# camera         2
# card          17
# os            34
# dtype: int64

# %%
df
# Out:
#                     model    price rating  \
# 0    Motorola Edge 40 Neo  ₹22,999     84
# 1     Xiaomi Redmi 13C 5G  ₹10,999     74
# 2    Motorola Moto G54 5G  ₹13,999     84
# 3    OnePlus Nord CE 3 5G  ₹24,953     84
# 4                Vivo V29  ₹30,899     85
# ..                    ...      ...    ...
# 955               Giva G8     ₹608    NaN
# 956      Snexian Guru 315     ₹608    NaN
# 957  Snexian Guru 311 New     ₹608    NaN
# 958    Oukitel WP21 Ultra  ₹48,500     85
# 959       itel it2175 Pro   ₹1,119    NaN
#
#                                                    sim  \
# 0              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# 1                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 2                   Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi
# 3    Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC, IR Bl...
# 4              Dual Sim, 3G, 4G, 5G, VoLTE, Wi-Fi, NFC
# ..                                                 ...
# 955                                           Dual Sim
# 956                                           Dual Sim
# 957                                           Dual Sim
# 958                       Dual Sim, 3G, 4G, Wi-Fi, NFC
# 959                                           Dual Sim
#
#                                              processor  \
# 0         Dimensity 7030, Octa Core, 2.5 GHz Processor
# 1    Dimensity 6100 Plus, Octa Core, 2.2 GHz Processor
# 2         Dimensity 7020, Octa Core, 2.2 GHz Processor
# 3       Snapdragon  782G, Octa Core, 2.7 GHz Processor
# 4        Snapdragon 778G, Octa Core, 2.4 GHz Processor
# ..                                                 ...
# 955                                  1.2 MHz Processor
# 956                           32 MB RAM, 32 MB inbuilt
# 957                                    1 MHz Processor
# 958            Helio G99, Octa Core, 2.2 GHz Processor
# 959                                  208 MHz Processor
#
#                            ram                                  battery  \
# 0     8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 68W Fast Charging
# 1     4 GB RAM, 128 GB inbuilt  5000 mAh Battery with 18W Fast Charging
# 2     8 GB RAM, 128 GB inbuilt  6000 mAh Battery with 33W Fast Charging
# 3     8 GB RAM, 128 GB inbuilt  5000 mAh Battery with 80W Fast Charging
# 4     8 GB RAM, 128 GB inbuilt  4600 mAh Battery with 80W Fast Charging
# ..                         ...                                      ...
# 955   32 MB RAM, 64 MB inbuilt                         1000 mAh Battery
# 956           1000 mAh Battery         1.8 inches, 128 x 160 px Display
# 957   32 MB RAM, 32 MB inbuilt                         1000 mAh Battery
# 958  12 GB RAM, 256 GB inbuilt  9800 mAh Battery with 66W Fast Charging
# 959     4 MB RAM, 4 MB inbuilt                         1200 mAh Battery
#
#                                                display  \
# 0    6.55 inches, 1080 x 2400 px, 144 Hz Display wi...
# 1    6.74 inches, 720 x 1600 px, 90 Hz Display with...
# 2    6.5 inches, 1080 x 2400 px, 120 Hz Display wit...
# 3    6.7 inches, 1080 x 2412 px, 120 Hz Display wit...
# 4    6.78 inches, 1260 x 2800 px, 120 Hz Display wi...
# ..                                                 ...
# 955                   1.8 inches, 128 x 160 px Display
# 956                                 0.3 MP Rear Camera
# 957                   1.8 inches, 240 x 320 px Display
# 958        6.78 inches, 1080 x 2460 px, 120 Hz Display
# 959                     2 inches, 128 x 160 px Display
#
#                                                 camera  \
# 0         50 MP + 13 MP Dual Rear & 32 MP Front Camera
# 1    50 MP + Depth Sensor Dual Rear & 5 MP Front Ca...
# 2          50 MP + 8 MP Dual Rear & 16 MP Front Camera
# 3    50 MP + 8 MP + 2 MP Triple Rear & 16 MP Front ...
# 4    50 MP + 8 MP + 2 MP Triple Rear & 50 MP Front ...
# ..                                                 ...
# 955                                 0.3 MP Rear Camera
# 956                  Memory Card Supported, upto 16 GB
# 957                                 1.3 MP Rear Camera
# 958  64 MP + 20 MP + 5 MP Triple Rear & 20 MP Front...
# 959                                 0.8 MP Rear Camera
#
#                                   card           os
# 0            Memory Card Not Supported  Android v13
# 1     Memory Card Supported, upto 1 TB  Android v13
# 2      Memory Card (Hybrid), upto 1 TB  Android v13
# 3      Memory Card (Hybrid), upto 1 TB  Android v13
# 4                          Android v13  No FM Radio
# ..                                 ...          ...
# 955              Memory Card Supported        v1.77
# 956                          Bluetooth          NaN
# 957              Memory Card Supported  No FM Radio
# 958               Memory Card (Hybrid)  Android v13
# 959  Memory Card Supported, upto 32 GB          NaN
#
# [960 rows x 11 columns]
